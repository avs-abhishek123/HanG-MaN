# %%
#HaNg-MaN

#importing the time module
import time

#welcoming the user
name = input("What is your name? ")

print ("Hello, " + name, "Time to play the game HangMan!")

print (" ")

#wait for 1 second
time.sleep(1)

print ("Start guessing , you have 10 turns and the letters coomon in the word and your guess will start appearing...")
time.sleep(0.5)

#The Secret is set here
the_secret_word = "secret"

#creates a variable with an empty value
User_guesses = ''

#determine the no. of turns
No_of_turns = 10

# Create a while loop

#check if the turns are more than zero
while No_of_turns > 0:         

    # make a counter that starts with zero
    fail = 0             

    # for every character in secret_word    
    for charecter in the_secret_word:      

    #we see if the charecter is in the player's guess
        if charecter in User_guesses:    
    
        # print then out the character
            print (charecter)

        else:
    
        # if not found, print a dash
            print ("_")     
       
        # and increase the failed counter with one
            fail += 1    

    # if failed is equal to zero

    # print You Won
    if fail == 0:        
        print ("You won the HanG~MaN game")  

    # exit the script
        break              

    print

    # ask the user go guess a character
    User_guess =input("guess a character:") 

    # set the players guess to guesses
    User_guesses += User_guess                    

    # if the guess is not found in the secret word
    if User_guess not in the_secret_word:  
 
     # turns counter decreases with 1 (now 9)
        No_of_turns -= 1        
 
    # print wrong
        print ("Wrong")    
 
    # how many turns are left
        print ("You have", + No_of_turns, 'more guesses')
 
    # if the turns are equal to zero
        if No_of_turns == 0:           
    
        # print You Loose
            print ("You Loose" )
# Out:
# What is your name? abhi
# Hello, abhi Time to play the game HangMan!
#
# Start guessing , you have 10 turns and the letters coomon in the word and your guess will start appearing...
# _
# _
# _
# _
# _
# _
# guess a character:dncsjcns
# Wrong
# You have 9 more guesses
# s
# _
# c
# _
# _
# _
# guess a character:sector
# Wrong
# You have 8 more guesses
# s
# e
# c
# r
# e
# t
# You won the HanG~MaN game
